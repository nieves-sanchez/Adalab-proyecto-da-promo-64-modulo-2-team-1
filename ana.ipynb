# %%
# Pasos previos al uso del API de Spotify.
# Importamos la librería de Python Spotipy

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = 'd18941f535f5419ab6a05e8fc0dc9875'
CLIENT_SECRET = 'd3ffe57bf5124fcb83f42c2882773c72'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
#Esto es una prueba de la información que podemos obtener siguiendo las INDICACIONES DE LA GUÍA
#Estamos buscando las canciones que sean de genero rock del 2020, la consulta lo ponemos en la query
datos = sp.search(q="genre:rock year:2020", type='track', limit=50, offset=0)
data_track_album = sp.search(q="genre:rock year:2020", type='track,album', limit=50, offset=0)#para ambos

# %%
datos
# DATOS es un diccionario cuya clave es 'tracks' y en cuyo valor encontramos nuevos diccionarios.
# Dentro de este, lo que más nos puede interesar es la clave 'items' que alberga una lista de diccionarios.
#

# %%
datos. keys()
# Out:
# dict_keys(['tracks'])

# %%
datos ['tracks']['items']
# Como hemos dicho, 'items' es una lista de diccionarios de la que debemos extraer información valiosa.

# %%
datos ['tracks']['items'][1] #Estamos accediendo al segundo elemento de 'items' para ver qué información nos arroja.
# Es decir, de este único elemento visualizamos toda su información.
# Debemos de tener claro que información concreta queremos extraer de aquí.

# %%
datos ['tracks']['items'][1].keys()
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
datos ['tracks']['items'][1]['artists']
# Lista de diccionarios.
# Del primer elemento de esta lista, queremos el valor de la clave 'name'.
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Ffb6ejR6Fe5IamqA5oRUF'},
#   'href': 'https://api.spotify.com/v1/artists/1Ffb6ejR6Fe5IamqA5oRUF',
#   'id': '1Ffb6ejR6Fe5IamqA5oRUF',
#   'name': 'Bring Me The Horizon',
#   'type': 'artist',
#   'uri': 'spotify:artist:1Ffb6ejR6Fe5IamqA5oRUF'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7I95CM75shzCjHuTzrepjM'},
#   'href': 'https://api.spotify.com/v1/artists/7I95CM75shzCjHuTzrepjM',
#   'id': '7I95CM75shzCjHuTzrepjM',
#   'name': 'Nova Twins',
#   'type': 'artist',
#   'uri': 'spotify:artist:7I95CM75shzCjHuTzrepjM'}]

# %%
datos ['tracks']['items'][1]['album'] # Dentro de 'álbum' lo que nos interesa es la fecha 'release_date' pudiendo acceder a su valor.

# %%
datos ['tracks']['items'][1]['album']['release_date']
# Out:
# '2020-10-30'
